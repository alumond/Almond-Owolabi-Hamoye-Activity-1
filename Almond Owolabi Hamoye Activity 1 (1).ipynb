# %%
import pandas  as pd
import numpy as np

# %%
csv_df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')
csv_df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
csv_df.groupby('Area')['Area'].count()
# Out:
# Area
# Algeria                        1313
# Angola                         1424
# Benin                          1285
# Botswana                       1378
# Burkina Faso                   1409
# Cabo Verde                     1260
# Cameroon                       1460
# Central African Republic       1344
# Chad                           1343
# Comoros                          45
# Congo                          1413
# Côte d'Ivoire                  1467
# Djibouti                       1095
# Egypt                          1488
# Eswatini                       1284
# Ethiopia                       1447
# Ethiopia PDR                     39
# Gabon                          1245
# Gambia                         1168
# Ghana                          1354
# Guinea                         1410
# Guinea-Bissau                  1128
# Kenya                          1560
# Lesotho                        1150
# Liberia                        1206
# Madagascar                     1439
# ...

# %%
csv_df.count()
# Out:
# Area Code       60943
# Area            60943
# Item Code       60943
# Item            60943
# Element Code    60943
# Element         60943
# Unit            60943
# Y2014           59354
# Y2015           59395
# Y2016           59408
# Y2017           59437
# Y2018           59507
# dtype: int64

# %%
csv_df.std()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4516\3977508714.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   csv_df.mean()
# C:\Users\dell\AppData\Local\Temp\ipykernel_4516\3977508714.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   csv_df.std()
# Area Code         72.605709
# Item Code        146.055739
# Element Code    2212.007033
# Y2014           1567.663696
# Y2015           1603.403984
# Y2016           1640.007194
# Y2017           1671.862359
# Y2018           1710.782658
# dtype: float64

# %%
csv_df.mean()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4516\1276477327.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   csv_df.mean()
# Area Code        134.265576
# Item Code       2687.176706
# Element Code    3814.856456
# Y2014            134.196282
# Y2015            135.235966
# Y2016            136.555222
# Y2017            140.917765
# Y2018            143.758381
# dtype: float64

# %%
csv_df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
csv_df['Area'].nunique()
# Out:
# 49

# %%
csv_df.groupby('Element')['Y2018'].count()
# Out:
# Element
# Domestic supply quantity                  5256
# Export Quantity                           3646
# Fat supply quantity (g/capita/day)        4987
# Feed                                      1225
# Food                                      4913
# Food supply (kcal/capita/day)             4969
# Food supply quantity (kg/capita/yr)       4877
# Import Quantity                           4945
# Losses                                    2008
# Other uses (non-food)                     1655
# Processing                                2003
# Production                                3846
# Protein supply quantity (g/capita/day)    4986
# Residuals                                 4616
# Seed                                       758
# Stock Variation                           4217
# Total Population - Both sexes               45
# Tourist consumption                        555
# Name: Y2018, dtype: int64

# %%
csv_df.sum()
# Out:
# Area Code                                                  252133
# Area            ZimbabweZimbabweZimbabweZimbabweZimbabweZimbab...
# Item Code                                                 3739292
# Item            PopulationPopulationGrand TotalGrand TotalGran...
# Element Code                                              5346770
# Element         Total Population - Both sexesDomestic supply q...
# Unit            1000 persons1000 tonneskcal/capita/dayg/capita...
# Y2014                                                    78366.34
# Y2015                                                    74041.79
# Y2016                                                    75638.88
# Y2017                                                    75919.34
# Y2018                                                    76581.41
# dtype: object

# %%
csv_df.groupby('Item')['Y2014'].sum()
# Out:
# Item
# Alcohol, Non-Food        2403.00
# Alcoholic Beverages    102410.11
# Animal Products         11935.65
# Animal fats            209460.54
# Apples and products      9499.23
#                          ...
# Vegetables, Other      155038.96
# Vegetal Products       107145.19
# Wheat and products     232670.13
# Wine                     4497.36
# Yams                   200396.96
# Name: Y2014, Length: 119, dtype: float64

# %%
csv_df.groupby('Element')['Y2014'].sum()
# Out:
# Element
# Domestic supply quantity                  1996716.35
# Export Quantity                            150020.64
# Fat supply quantity (g/capita/day)          10225.56
# Feed                                       216927.89
# Food                                      1212332.49
# Food supply (kcal/capita/day)              454257.00
# Food supply quantity (kg/capita/yr)         49650.63
# Import Quantity                            274144.48
# Losses                                     153223.00
# Other uses (non-food)                       78718.13
# Processing                                 282923.00
# Production                                1931287.75
# Protein supply quantity (g/capita/day)      11836.46
# Residuals                                   30149.00
# Seed                                        21922.92
# Stock Variation                             58749.83
# Total Population - Both sexes             1031585.00
# Tourist consumption                           416.00
# ...

# %%
csv_df.groupby('Element', as_index=False)['Y2018'].sum()
# Out:
#                                    Element     Y2018
# 0                 Domestic supply quantity  17860.73
# 1                          Export Quantity    416.71
# 2       Fat supply quantity (g/capita/day)    207.99
# 3                                     Feed    141.32
# 4                                     Food   8821.37
# 5            Food supply (kcal/capita/day)   7627.00
# 6      Food supply quantity (kg/capita/yr)    611.22
# 7                          Import Quantity   1673.84
# 8                                   Losses    891.00
# 9                    Other uses (non-food)    106.06
# 10                              Processing   8300.00
# 11                              Production  16161.60
# 12  Protein supply quantity (g/capita/day)    176.57
# 13                               Residuals   -546.00
# 14                                    Seed    140.00
# 15                         Stock Variation   -447.00
# 16           Total Population - Both sexes  14439.00

# %%
csv_df.groupby('Element')['Y2018'].agg(['mean','std'])
# Out:
#                                                 mean         std
# Element
# Domestic supply quantity                  152.655812  518.419330
# Export Quantity                             5.342436   17.192411
# Fat supply quantity (g/capita/day)          1.857054    6.976521
# Feed                                        4.282424    8.982064
# Food                                       80.930000  227.705017
# Food supply (kcal/capita/day)              68.098214  270.731174
# Food supply quantity (kg/capita/yr)         5.607523   15.771852
# Import Quantity                            15.941333   56.118210
# Losses                                     16.500000   41.276221
# Other uses (non-food)                       2.719487   10.088522
# Processing                                136.065574  656.813923
# Production                                166.614433  538.838630
# Protein supply quantity (g/capita/day)      1.576518    6.108501
# ...

# %%
csv_df.groupby('Element', as_index=False)['Y2014'].sum()
# Out:
#                                    Element     Y2014
# 0                 Domestic supply quantity  18538.82
# 1                          Export Quantity    722.26
# 2       Fat supply quantity (g/capita/day)    215.70
# 3                                     Feed    176.50
# 4                                     Food   9001.17
# 5            Food supply (kcal/capita/day)   7942.00
# 6      Food supply quantity (kg/capita/yr)    662.42
# 7                          Import Quantity   2490.58
# 8                                   Losses    783.00
# 9                    Other uses (non-food)    192.16
# 10                              Processing   8492.00
# 11                              Production  16130.50
# 12  Protein supply quantity (g/capita/day)    184.23
# 13                               Residuals   -252.00
# 14                                    Seed    144.00
# 15                         Stock Variation   -644.00
# 16           Total Population - Both sexes  13587.00

# %%
csv_df.groupby('Element', as_index=False)['Y2015'].sum()
# Out:
#                                    Element     Y2015
# 0                 Domestic supply quantity  17012.90
# 1                          Export Quantity    602.12
# 2       Fat supply quantity (g/capita/day)    212.61
# 3                                     Feed    161.08
# 4                                     Food   8674.69
# 5            Food supply (kcal/capita/day)   7646.00
# 6      Food supply quantity (kg/capita/yr)    627.92
# 7                          Import Quantity   3244.03
# 8                                   Losses    746.00
# 9                    Other uses (non-food)    173.13
# 10                              Processing   7914.00
# 11                              Production  14032.00
# 12  Protein supply quantity (g/capita/day)    175.31
# 13                               Residuals   -780.00
# 14                                    Seed    128.00
# 15                         Stock Variation   -343.00
# 16           Total Population - Both sexes  13815.00

# %%
csv_df.groupby('Element', as_index=False)['Y2016'].sum()
# Out:
#                                    Element     Y2016
# 0                 Domestic supply quantity  17228.21
# 1                          Export Quantity    470.36
# 2       Fat supply quantity (g/capita/day)    205.50
# 3                                     Feed    136.74
# 4                                     Food   8707.40
# 5            Food supply (kcal/capita/day)   7536.00
# 6      Food supply quantity (kg/capita/yr)    620.30
# 7                          Import Quantity   3653.98
# 8                                   Losses    776.00
# 9                    Other uses (non-food)    107.07
# 10                              Processing   8261.00
# 11                              Production  14267.60
# 12  Protein supply quantity (g/capita/day)    172.72
# 13                               Residuals   -882.00
# 14                                    Seed    127.00
# 15                         Stock Variation    221.00
# 16           Total Population - Both sexes  14030.00

# %%
csv_df.groupby('Element', as_index=False)['Y2017'].sum()
# Out:
#                                    Element     Y2017
# 0                 Domestic supply quantity  17125.73
# 1                          Export Quantity    414.71
# 2       Fat supply quantity (g/capita/day)    204.52
# 3                                     Feed    194.32
# 4                                     Food   8770.37
# 5            Food supply (kcal/capita/day)   7563.00
# 6      Food supply quantity (kg/capita/yr)    615.88
# 7                          Import Quantity   2083.84
# 8                                   Losses   1132.00
# 9                    Other uses (non-food)    100.06
# 10                              Processing   7852.00
# 11                              Production  15913.60
# 12  Protein supply quantity (g/capita/day)    175.31
# 13                               Residuals  -1083.00
# 14                                    Seed    162.00
# 15                         Stock Variation    458.00
# 16           Total Population - Both sexes  14237.00

# %%
csv_df.groupby('Element', as_index=False)['Y2018'].sum()
# Out:
#                                    Element     Y2018
# 0                 Domestic supply quantity  17860.73
# 1                          Export Quantity    416.71
# 2       Fat supply quantity (g/capita/day)    207.99
# 3                                     Feed    141.32
# 4                                     Food   8821.37
# 5            Food supply (kcal/capita/day)   7627.00
# 6      Food supply quantity (kg/capita/yr)    611.22
# 7                          Import Quantity   1673.84
# 8                                   Losses    891.00
# 9                    Other uses (non-food)    106.06
# 10                              Processing   8300.00
# 11                              Production  16161.60
# 12  Protein supply quantity (g/capita/day)    176.57
# 13                               Residuals   -546.00
# 14                                    Seed    140.00
# 15                         Stock Variation   -447.00
# 16           Total Population - Both sexes  14439.00

# %%
g = csv_df.groupby('Area')
g

# %%
g.get_group('Algeria')
# Out:
#       Area Code     Area  Item Code           Item  Element Code  \
# 0             4  Algeria       2501     Population           511
# 1             4  Algeria       2501     Population          5301
# 2             4  Algeria       2901    Grand Total           664
# 3             4  Algeria       2901    Grand Total           674
# 4             4  Algeria       2901    Grand Total           684
# ...         ...      ...        ...            ...           ...
# 1308          4  Algeria       2899  Miscellaneous          5142
# 1309          4  Algeria       2899  Miscellaneous           645
# 1310          4  Algeria       2899  Miscellaneous           664
# 1311          4  Algeria       2899  Miscellaneous           674
# 1312          4  Algeria       2899  Miscellaneous           684
#
#                                      Element             Unit     Y2014  \
# 0              Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
g.max()
# Out:
#                              Area Code  Item Code          Item  Element Code  \
# Area
# Algeria                              4       2961          Yams          5911
# Angola                               7       2961          Yams          5911
# Benin                               53       2961          Yams          5911
# Botswana                            20       2961          Yams          5911
# Burkina Faso                       233       2961          Yams          5911
# Cabo Verde                          35       2961          Yams          5911
# Cameroon                            32       2961          Yams          5911
# Central African Republic            37       2961          Yams          5911
# Chad                                39       2961          Yams          5911
# Comoros                             45       2782  Pelagic Fish          5911
# Congo                               46       2961          Yams          5911
# ...

# %%
g.min()
# Out:
#                              Area Code  Item Code                     Item  \
# Area
# Algeria                              4       2501        Alcohol, Non-Food
# Angola                               7       2501        Alcohol, Non-Food
# Benin                               53       2501        Alcohol, Non-Food
# Botswana                            20       2501        Alcohol, Non-Food
# Burkina Faso                       233       2501        Alcohol, Non-Food
# Cabo Verde                          35       2501        Alcohol, Non-Food
# Cameroon                            32       2501        Alcohol, Non-Food
# Central African Republic            37       2501        Alcohol, Non-Food
# Chad                                39       2501        Alcohol, Non-Food
# Comoros                             45       2761              Cephalopods
# Congo                               46       2501        Alcohol, Non-Food
# ...

# %%
g.mean()
# Out:
#                              Area Code    Item Code  Element Code       Y2014  \
# Area
# Algeria                            4.0  2690.063214   3821.726580  248.513347
# Angola                             7.0  2682.519663   3872.955056  151.367504
# Benin                             53.0  2687.698054   3776.513619   94.440632
# Botswana                          20.0  2688.608128   3816.969521   16.414342
# Burkina Faso                     233.0  2681.898510   3854.679205   76.013987
# Cabo Verde                        35.0  2695.830159   3799.802381   11.841543
# Cameroon                          32.0  2682.245205   3878.901370  150.089848
# Central African Republic          37.0  2684.186012   3771.647321   22.106938
# Chad                              39.0  2685.427401   3803.689501   51.355273
# Comoros                           45.0  2766.977778   5370.688889    0.711111
# Congo                             46.0  2683.672328   3853.899505   28.002359
# ...
